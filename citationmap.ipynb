# %%
# %pip install hips
# Out:
# Requirement already satisfied: hips in /blue/adamginsburg/adamginsburg/repos/hips (0.3.dev372)
# Requirement already satisfied: numpy>=1.11 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from hips) (1.23.1)
# Requirement already satisfied: astropy>=1.3 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from hips) (6.0.dev783+g1ae27848e2)
# Requirement already satisfied: astropy-healpix in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from hips) (0.6)
# Requirement already satisfied: scikit-image in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from hips) (0.18.3)
# Requirement already satisfied: Pillow in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from hips) (8.4.0)
# Requirement already satisfied: PyYAML>=3.13 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from astropy>=1.3->hips) (6.0)
# Requirement already satisfied: pyerfa>=2.0 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from astropy>=1.3->hips) (2.0.0.1)
# Requirement already satisfied: packaging>=19.0 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from astropy>=1.3->hips) (21.3)
# Requirement already satisfied: astropy-iers-data>=0.2023.10.04.22.08.17 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from astropy>=1.3->hips) (0.2023.10.9.0.29.17)
# Requirement already satisfied: tifffile>=2019.7.26 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from scikit-image->hips) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from scikit-image->hips) (2.10.1)
# Requirement already satisfied: networkx>=2.0 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from scikit-image->hips) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from scikit-image->hips) (1.1.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from scikit-image->hips) (3.7.1)
# Requirement already satisfied: scipy>=1.0.1 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from scikit-image->hips) (1.9.0)
# Requirement already satisfied: cycler>=0.10 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (5.8.0)
# Requirement already satisfied: zipp>=3.1.0 in /blue/adamginsburg/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (3.8.0)
# Requirement already satisfied: six>=1.5 in /blue/adamginsburg/adamginsburg/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image->hips) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from astropy.coordinates import SkyCoord
from hips import WCSGeometry

geometry = WCSGeometry.create(
     skydir=SkyCoord(0, 0, unit='deg', frame='galactic'),
     width=2000, height=1000, fov="3 deg",
     coordsys='galactic', projection='AIT',
)

hips_survey = 'CDS/P/DSS2/red'
hips_survey = 'simbad-biblio/2021'
hips_survey = 'CDS/P/DM/simbad-biblio/pub-dates/2022'

# %%
from hips import make_sky_image
result = make_sky_image(geometry, hips_survey, 'fits')
# Out:
# Fetching tiles: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.23it/s]
# Drawing tiles: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.17it/s]

# %%
result.plot()
